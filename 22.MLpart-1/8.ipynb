# %% [markdown]
# ### Q1.Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose you have collected data on the amount of time students spend studying for an exam and their final exam scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.
#
# ```python
# # Python Code for Q1
# import numpy as np
# from scipy.stats import pearsonr
#
# # Example data: hours studied and exam scores
# hours_studied = np.array([10, 9, 8, 6, 4, 5, 3])
# exam_scores = np.array([95, 88, 84, 75, 65, 70, 50])
#
# # Calculate Pearson correlation coefficient
# corr, _ = pearsonr(hours_studied, exam_scores)
#
# print(f'Pearson correlation coefficient: {corr:.3f}')
# ```
#
# **Interpretation:**
# The Pearson correlation coefficient (r) ranges between -1 and 1. A value of 1 indicates a perfect positive linear relationship, -1 indicates a perfect negative linear relationship, and 0 indicates no linear relationship.
#
# ---
#
# ### Q2.Spearman's rank correlation is a measure of the monotonic relationship between two variables. Suppose you have collected data on the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two variables and interpret the result.
#
# ```python
# # Python Code for Q2
# from scipy.stats import spearmanr
#
# # Example data: hours of sleep and job satisfaction
# sleep_hours = np.array([8, 7, 6, 5, 6, 7, 8])
# job_satisfaction = np.array([9, 8, 7, 5, 6, 8, 9])
#
# # Calculate Spearman's rank correlation
# rank_corr, _ = spearmanr(sleep_hours, job_satisfaction)
#
# print(f'Spearman rank correlation coefficient: {rank_corr:.3f}')
# ```
#
# **Interpretation:**
# The Spearman's rank correlation coefficient measures the strength of the monotonic relationship between two variables. A positive value suggests that as one variable increases, the other tends to increase as well.
#
# ---
#
# ### Q3.Suppose you are conducting a study to examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation between these two variables and compare the results.
#
# ```python
# # Python Code for Q3
# # Example data: exercise hours and BMI
# exercise_hours = np.random.randint(1, 10, 50)
# bmi = np.random.randint(18, 35, 50)
#
# # Calculate Pearson correlation
# pearson_corr, _ = pearsonr(exercise_hours, bmi)
#
# # Calculate Spearman's rank correlation
# spearman_corr, _ = spearmanr(exercise_hours, bmi)
#
# print(f'Pearson correlation: {pearson_corr:.3f}')
# print(f'Spearman rank correlation: {spearman_corr:.3f}')
# ```
#
# **Comparison:**
# Pearson measures linear relationships, while Spearman captures monotonic relationships. Differences in the values can indicate a non-linear monotonic relationship.
#
# ---
#
# ### Q4. A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity. Calculate the Pearson correlation coefficient between these two variables.
#
# ```python
# # Python Code for Q4
# # Example data: hours watching TV and physical activity level
# tv_hours = np.random.randint(1, 5, 50)
# physical_activity = np.random.randint(1, 10, 50)
#
# # Calculate Pearson correlation coefficient
# corr_tv_activity, _ = pearsonr(tv_hours, physical_activity)
#
# print(f'Pearson correlation between TV hours and physical activity: {corr_tv_activity:.3f}')
# ```
#
# **Interpretation:**
# A negative correlation suggests that more hours spent watching TV might be associated with lower levels of physical activity.
#
# ---
#
# ### Q5. A survey was conducted to examine the relationship between age and preference for a particular brand of soft drink. The survey results are shown below:
#
# | Age (Years)  | Preference        |
# |--------------|-------------------|
# | 25           | Coke              |
# | 42           | Pepsi             |
# | 37           | Mountain Dew      |
# | 19           | Coke              |
# | 31           | Pepsi             |
# | 28           | Coke              |
#
# **Answer:**
# Since the data involves categorical preferences, a chi-square test for independence would be appropriate to test the relationship between age and soft drink preference.
#
# ---
#
# ### Q6. A company is interested in examining the relationship between the number of sales calls made per day and the number of sales made per week. The company collected data on both variables from a sample of 30 sales representatives.
#
# ```python
# # Python Code for Q6
# # Example data: sales calls and weekly sales
# sales_calls = np.random.randint(10, 50, 30)
# weekly_sales = np.random.randint(5, 20, 30)
#
# # Calculate Pearson correlation coefficient
# corr_sales, _ = pearsonr(sales_calls, weekly_sales)
#
# print(f'Pearson correlation between sales calls and weekly sales: {corr_sales:.3f}')
# ```
#
# **Interpretation:**
# A positive correlation suggests that making more sales calls is associated with higher sales per week.
#
#
# ```
